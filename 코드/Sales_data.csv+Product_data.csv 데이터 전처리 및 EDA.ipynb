# %%
# 데이터 분석 패키지
import pandas as pd

# 행렬 연산 패키지
import numpy as np

# 데이터 시각화 패키지
import matplotlib
import matplotlib.pyplot as plt

#데이터 시각화(추세 등) 패키지
import seaborn as sns

# 가설검정 및 통계분석 패키지
from scipy import stats


from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.cm
print(matplotlib.cm.cmap_d.keys())
# Out:
# KeysView(<matplotlib.cm._DeprecatedCmapDictWrapper object at 0x7fa382c12040>)

# %%
df_product_2 = pd.read_csv('/Users/juyeon/Desktop/빅데이터 프로젝트/DATA/A2_유아용품/product_data_전처리2.csv')
df_product_2
# Out:
#      물품대분류                               상품명  물품판매량   제품단가  브랜드명 물품중분류 기저귀 유형  \
# 0       FC        (1+1) 좋은느낌 입는 오버나이트 대형 8개입     15      0  좋은느낌   생리대    NaN
# 1       FC        (1+1) 좋은느낌 입는 오버나이트 중형 8개입     10      0  좋은느낌   생리대    NaN
# 2       FC  (1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)     27      0   화이트   생리대    NaN
# 3       FC  (1+1) 화이트 입는 오버나이트 중형 M 8개입 (EA)     12      0   화이트   생리대    NaN
# 4       FC   (핫딜위크/1+1) 좋은느낌 입는 오버나이트 대형 8개입      4      0  좋은느낌   생리대    NaN
# ...    ...                               ...    ...    ...   ...   ...    ...
# 3043    팬티    하기스 에어솔솔 썸머팬티 6단계 여아용 68매(팬티형)      4  47360   하기스   기저귀    팬티형
# 3044    팬티      하기스 에어솔솔 팬티 4단계 남아용 96매(팬티형)     18  71040   하기스   기저귀    팬티형
# 3045    팬티      하기스 에어솔솔 팬티 4단계 여아용 96매(팬티형)     17  66861   하기스   기저귀    팬티형
# 3046    팬티      하기스 에어솔솔 팬티 5단계 남아용 80매(팬티형)     81  68994   하기스   기저귀    팬티형
# 3047    팬티      하기스 에어솔솔 팬티 5단계 여아용 80매(팬티형)     34  76612   하기스   기저귀    팬티형
#
#       기저귀 단계
# 0        NaN
# ...

# %%
conditionlist = [
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '밴드형') & (df_product_2['기저귀 단계'] == 1.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '밴드형') & (df_product_2['기저귀 단계'] == 2.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '팬티형') & (df_product_2['기저귀 단계'] == 2.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '밴드형') & (df_product_2['기저귀 단계'] == 3.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '팬티형') & (df_product_2['기저귀 단계'] == 3.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '밴드형') & (df_product_2['기저귀 단계'] == 4.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '팬티형') & (df_product_2['기저귀 단계'] == 4.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '밴드형') & (df_product_2['기저귀 단계'] == 5.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '팬티형') & (df_product_2['기저귀 단계'] == 5.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '팬티형') & (df_product_2['기저귀 단계'] == 6.0),
    (df_product_2['물품중분류'] == '기저귀') & (df_product_2['기저귀 유형'] == '팬티형') & (df_product_2['기저귀 단계'] == 7.0)]
choicelist = ['신생아','영아','영아','영아','영아','영아','영아','유아','유아','유아','유아']
df_product_2['Age_Range'] = np.select(conditionlist, choicelist, default='NaN')

print(df_product_2)
# Out:
#      물품대분류                               상품명  물품판매량   제품단가  브랜드명 물품중분류 기저귀 유형  \
# 0       FC        (1+1) 좋은느낌 입는 오버나이트 대형 8개입     15      0  좋은느낌   생리대    NaN
# 1       FC        (1+1) 좋은느낌 입는 오버나이트 중형 8개입     10      0  좋은느낌   생리대    NaN
# 2       FC  (1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)     27      0   화이트   생리대    NaN
# 3       FC  (1+1) 화이트 입는 오버나이트 중형 M 8개입 (EA)     12      0   화이트   생리대    NaN
# 4       FC   (핫딜위크/1+1) 좋은느낌 입는 오버나이트 대형 8개입      4      0  좋은느낌   생리대    NaN
# ...    ...                               ...    ...    ...   ...   ...    ...
# 3043    팬티    하기스 에어솔솔 썸머팬티 6단계 여아용 68매(팬티형)      4  47360   하기스   기저귀    팬티형
# 3044    팬티      하기스 에어솔솔 팬티 4단계 남아용 96매(팬티형)     18  71040   하기스   기저귀    팬티형
# 3045    팬티      하기스 에어솔솔 팬티 4단계 여아용 96매(팬티형)     17  66861   하기스   기저귀    팬티형
# 3046    팬티      하기스 에어솔솔 팬티 5단계 남아용 80매(팬티형)     81  68994   하기스   기저귀    팬티형
# 3047    팬티      하기스 에어솔솔 팬티 5단계 여아용 80매(팬티형)     34  76612   하기스   기저귀    팬티형
#
#       기저귀 단계 Age_Range
# ...

# %%
df_product_2.to_csv('AGE_RANGE추가.csv',index=False)

# %% [markdown]
# # Sales + Product

# %%
data_1 = pd.read_csv("/Users/juyeon/Desktop/빅데이터 프로젝트/DATA/A2_유아용품/Sales_data.csv")
data_1.head()
# Out:
# /var/folders/f2/nhwmstw91jvf4lfg4wk_7j440000gn/T/ipykernel_29508/656815408.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_1 = pd.read_csv("/Users/juyeon/Desktop/빅데이터 프로젝트/DATA/A2_유아용품/Sales_data.csv")
#               주문번호         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 0  201905052342970  2019-05-06  2019-05-07  2019-05-11        4.0
# 1  202002203424450  2020-02-20  2020-02-21  2020-02-23       14.0
# 2  201902282095385  2019-02-28  2019-03-01  2019-03-05        NaN
# 3  201905132367003  2019-05-13  2019-05-14  2019-05-16       66.0
# 4  201905092356247  2019-05-10  2019-05-11  2019-05-13        5.0
#
#               고객번호   구매금액   결제금액 물품대분류                               상품명
# 0  201812310749735  25800  16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)
# 1  201812310749735  51200  37769    팬티  NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)
# 2  201812310749770   5610   3800   FMC            크리넥스？키즈용？화장지？3겹？27m 8롤
# ...

# %%
# 결제금액 -값 제거
index1 = data_1[data_1['결제금액'] == -35166].index
data_1 = data_1.drop(index1)

# %%
# Age_range 열 추가
conditionlist = [
    (data_1['구매시월령(수정)'] >= -10) & (data_1['구매시월령(수정)'] <= -1),
    (data_1['구매시월령(수정)'] >= 0) & (data_1['구매시월령(수정)'] <= 1),
    (data_1['구매시월령(수정)'] >= 2) & (data_1['구매시월령(수정)'] <= 12),
    (data_1['구매시월령(수정)'] >= 13) & (data_1['구매시월령(수정)'] <= 83),
    (data_1['구매시월령(수정)'] >= 84) & (data_1['구매시월령(수정)'] <= 144),
    (data_1['구매시월령(수정)'] >= 144)]

choicelist = ['태아','신생아','영아','유아','소아','그외']
data_1['Age_Range'] = np.select(conditionlist, choicelist, default='Nan')

print(data_1)
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905092356247  2019-05-10  2019-05-11  2019-05-13
# ...                            ...         ...         ...         ...
# 199994  20200724113704-52679491210  2020-07-24  2020-07-25  2020-07-27
# 199995  20200729134816-18220910068  2020-07-29  2020-07-30  2020-08-01
# 199996  20200803080150-09054399128  2020-08-03  2020-08-04  2020-08-07
# 199997  20200805171023-18783441109  2020-08-06  2020-08-07  2020-08-11
# 199998  20200805224157-34181488371  2020-08-06  2020-08-07  2020-08-09
#
#         구매시월령(수정)                  고객번호   구매금액   결제금액 물품대분류  \
# ...

# %%
data_2 = pd.read_csv("/Users/juyeon/Desktop/빅데이터 프로젝트/DATA/A2_유아용품/AGE_RANGE추가.csv")
data_2.head()
# Out:
#   물품대분류                               상품명  물품판매량  제품단가  브랜드명 물품중분류 기저귀 유형  \
# 0    FC        (1+1) 좋은느낌 입는 오버나이트 대형 8개입     15     0  좋은느낌   생리대    NaN
# 1    FC        (1+1) 좋은느낌 입는 오버나이트 중형 8개입     10     0  좋은느낌   생리대    NaN
# 2    FC  (1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)     27     0   화이트   생리대    NaN
# 3    FC  (1+1) 화이트 입는 오버나이트 중형 M 8개입 (EA)     12     0   화이트   생리대    NaN
# 4    FC   (핫딜위크/1+1) 좋은느낌 입는 오버나이트 대형 8개입      4     0  좋은느낌   생리대    NaN
#
#    기저귀 단계 Age_Range
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN
# 3     NaN       NaN
# 4     NaN       NaN

# %%
df_raw_LEFT_JOIN = pd.merge(data_1, data_2, left_on='상품명', right_on='상품명', how='left')

# %%
df_raw_LEFT_JOIN
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# ...                            ...         ...         ...         ...
# 210033  20200724113704-52679491210  2020-07-24  2020-07-25  2020-07-27
# 210034  20200729134816-18220910068  2020-07-29  2020-07-30  2020-08-01
# 210035  20200803080150-09054399128  2020-08-03  2020-08-04  2020-08-07
# 210036  20200805171023-18783441109  2020-08-06  2020-08-07  2020-08-11
# 210037  20200805224157-34181488371  2020-08-06  2020-08-07  2020-08-09
#
#         구매시월령(수정)                  고객번호   구매금액   결제금액 물품대분류_x  \
# ...

# %%
df_sample_1 = df_raw_LEFT_JOIN.drop(['물품대분류_y','물품판매량','제품단가'],axis =1)

# %%
df_sample_1
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# ...                            ...         ...         ...         ...
# 210033  20200724113704-52679491210  2020-07-24  2020-07-25  2020-07-27
# 210034  20200729134816-18220910068  2020-07-29  2020-07-30  2020-08-01
# 210035  20200803080150-09054399128  2020-08-03  2020-08-04  2020-08-07
# 210036  20200805171023-18783441109  2020-08-06  2020-08-07  2020-08-11
# 210037  20200805224157-34181488371  2020-08-06  2020-08-07  2020-08-09
#
#         구매시월령(수정)                  고객번호   구매금액   결제금액 물품대분류_x  \
# ...

# %%
# True or False 행 추가
conditionlist = [
    (df_sample_1['Age_Range_x'] == df_sample_1['Age_Range_y']),
    (df_sample_1['Age_Range_x'] != df_sample_1['Age_Range_y'])
]

choicelist = ['TRUE','FALSE']
df_sample_1['Age_Range일치여부'] = np.select(conditionlist, choicelist, default='Nan')

print(df_sample_1)
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 0                  201905052342970  2019-05-06  2019-05-07  2019-05-11
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 2                  201902282095385  2019-02-28  2019-03-01  2019-03-05
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 4                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# ...                            ...         ...         ...         ...
# 210033  20200724113704-52679491210  2020-07-24  2020-07-25  2020-07-27
# 210034  20200729134816-18220910068  2020-07-29  2020-07-30  2020-08-01
# 210035  20200803080150-09054399128  2020-08-03  2020-08-04  2020-08-07
# 210036  20200805171023-18783441109  2020-08-06  2020-08-07  2020-08-11
# 210037  20200805224157-34181488371  2020-08-06  2020-08-07  2020-08-09
#
#         구매시월령(수정)                  고객번호   구매금액   결제금액 물품대분류_x  \
# ...

# %%
df_sample_2 = df_sample_1[(df_sample_1['물품중분류']=='기저귀')]

# %%
df_sample_2[['Age_Range일치여부']]
# Out:
#        Age_Range일치여부
# 1               TRUE
# 3              FALSE
# 4              FALSE
# 5               TRUE
# 6               TRUE
# ...              ...
# 210023         FALSE
# 210024         FALSE
# 210025         FALSE
# 210029          TRUE
# 210035          TRUE
#
# [96340 rows x 1 columns]

# %%
df_sample_2['Age_Range일치여부'].value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# TRUE     62.038613244758146%
# FALSE     37.96138675524185%
# Name: Age_Range일치여부, dtype: object

# %%
df_weekend = df_sample_1['기저귀유형'].value_counts()
df_weekend

# %%
df_diaper_sum = pd.pivot_table(data=df_sample_1, index = '기저귀 유형', values = '결제금액', aggfunc = 'sum')
df_diaper_sum
# Out:
#               결제금액
# 기저귀 유형
# 밴드형     2117726610
# 팬티형     1255585005

# %%
df_diaper_sum.plot.bar(figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='기저귀 유형'>

# %%
df_raw_LEFT_JOIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210038 entries, 0 to 210037
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   주문번호         210038 non-null  object
#  1   구매일          210038 non-null  object
#  2   배송시작일        210038 non-null  object
#  3   배송완료일        210038 non-null  object
#  4   구매시월령(수정)    177105 non-null  float64
#  5   고객번호         210038 non-null  object
#  6   구매금액         210038 non-null  int64
#  7   결제금액         210038 non-null  int64
#  8   물품대분류_x      210038 non-null  object
#  9   상품명          210038 non-null  object
#  10  Age_Range_x  210038 non-null  object
#  11  물품대분류_y      210038 non-null  object
#  12  물품판매량        210038 non-null  int64
#  13  제품단가         210038 non-null  int64
#  14  브랜드명         209926 non-null  object
#  15  물품중분류        183874 non-null  object
#  16  기저귀 유형       96447 non-null   object
#  17  기저귀 단계       95041 non-null   float64
# ...

# %%
df_month.sort_index(inplace = True);
df_month.plot.bar(figsize = (10,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df_month.sort_index(inplace = True);
#       2 df_month.plot.bar(figsize = (10,10))
#
# NameError: name 'df_month' is not defined
